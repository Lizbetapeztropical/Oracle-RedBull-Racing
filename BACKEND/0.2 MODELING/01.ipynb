# %%
# =========================
# LIBRARIES
# =========================

import pandas as pd
import numpy as np

from sklearn.preprocessing import (
    StandardScaler,
    LabelEncoder
)

from sklearn.impute import SimpleImputer

import os

# %%
# =========================
# LOAD DATASETS
# =========================

df = pd.read_csv("merged_dataset.csv")
tweets = pd.read_csv("tweets.csv")
# Out:
# /var/folders/cz/0k6hjthd6qq3l1zbk8f_p8sw0000gn/T/ipykernel_47659/3933217006.py:6: DtypeWarning: Columns (5,6,7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets = pd.read_csv("tweets.csv")

# %%
# ordenar cronológicamente

df = df.sort_values(by=["YEAR", "RACEID"])

# %%
## Feature Engineering

# %%
df["ROLLING_POINTS"] = (
    df.groupby("DRIVERID")["POINTS"]
    .transform(lambda x: x.rolling(5, min_periods=1).mean())
)

# %%
df["ROLLING_LAP"] = (
    df.groupby("DRIVERID")["LAPMEAN"]
    .transform(lambda x: x.rolling(5, min_periods=1).mean())
)

# %%
df["LAP_CONSISTENCY"] = (
    df.groupby("DRIVERID")["LAPMEAN"]
    .transform(lambda x: x.rolling(5).std())
)

# %%
df["RACE_INTERRUPTIONS"] = (
    df["SC_COUNT"] + df["PS_COUNT"]
)

# %%
df["OVERTAKE_RATIO"] = (
    df["OVERTAKEN_POSITIONS_TOTAL"] / df["LAPS"]
)

# %%
## EMBEDDINGS

# %%
driver_encoder = LabelEncoder()
race_encoder = LabelEncoder()

df["DRIVER_ENCODED"] = driver_encoder.fit_transform(df["DRIVERREF"])
df["RACE_ENCODED"] = race_encoder.fit_transform(df["NAME_YEAR"])

# %%
df.head()
# Out:
#        RACEID    POINTS  DRIVERID    DRIVERREF  LAPS  MILLISECONDS     SCORE  \
# 27285     833 -0.375795       579       fangio  62.0  7.105023e+06  5.769466
# 27530     833 -0.375795       589       chiron  26.0  2.979526e+06  5.769466
# 28129     833 -0.375795       619       gerard  67.0  7.678009e+06  5.769466
# 28299     833 -0.316728       627       rosier  68.0  7.792606e+06  5.769466
# 28539     833 -0.375795       640  graffenried  36.0  4.125497e+06  5.769466
#
#        WEATHER_cloudy  OVERTAKEN_POSITIONS_TOTAL  DNF_COUNT  ... LAPMEAN  \
# 27285             0.0                        0.0       11.0  ...     NaN
# 27530             0.0                        0.0       11.0  ...     NaN
# 28129             0.0                        0.0       11.0  ...     NaN
# 28299             0.0                        0.0       11.0  ...     NaN
# 28539             0.0                        0.0       11.0  ...     NaN
#
#        PS_COUNT  SC_COUNT  ROLLING_POINTS  ROLLING_LAP  LAP_CONSISTENCY  \
# 27285       NaN       NaN       -0.375795          NaN              NaN
# 27530       NaN       NaN       -0.375795          NaN              NaN
# 28129       NaN       NaN       -0.375795          NaN              NaN
# 28299       NaN       NaN       -0.316728          NaN              NaN
# 28539       NaN       NaN       -0.375795          NaN              NaN
#
#        RACE_INTERRUPTIONS  OVERTAKE_RATIO  DRIVER_ENCODED  RACE_ENCODED
# 27285                 NaN             0.0             241             1
# 27530                 NaN             0.0             159             1
# 28129                 NaN             0.0             295             1
# 28299                 NaN             0.0             678             1
# 28539                 NaN             0.0             314             1
#
# [5 rows x 22 columns]

# %%
df["ROLLING_POINTS"] = (
    df.groupby("DRIVERID")["POINTS"]
    .transform(lambda x: x.rolling(5, min_periods=1).mean())
)

# %%
# =========================
# EXPORT PROCESSED DATASET
# =========================

df.to_csv("processed_dataset.csv", index=False)

print("processed_dataset.csv saved successfully")
# Out:
# processed_dataset.csv saved successfully
